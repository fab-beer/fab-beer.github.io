# %%
#!/usr/bin/env python

import fill_untappd
import yaml, json, sqlite3,  dateparser,os, sys
from pprint import pprint
# from airtable import Airtable
import pandas as pd

# %%
conn = sqlite3.connect("./db/untappd.db")
df = pd.read_sql_query("select * from checkins;", conn)
jsons  = df.json.apply(lambda j: json.loads(j))

venues = jsons.apply(
    lambda x: 
    pd.concat([
        pd.Series(x["venue"]),
        pd.Series(x["user"])[["user_name"]],
        pd.Series(x["beer"]),
        pd.Series(x)[["checkin_id","created_at","rating_score"]]
        ])
        )

venues_info = pd.concat([venues, 
pd.concat([
    venues['contact'].apply(lambda x: pd.Series(x)),
    venues['location'].apply(lambda x: pd.Series(x)),
], axis = 1)],axis=1).set_index(["venue_slug","beer_slug"])

venue_users = venues_info.groupby(["venue_slug","beer_slug"]).user_name.apply(','.join).rename("user_names")
venue_rating = venues_info.groupby(["venue_slug","beer_slug"]).rating_score.sum().rename("total_rating")
venue_counts = venues_info.groupby(["venue_slug","beer_slug"]).size().rename("n_checkins").astype(int)
venue_last_checkin = venues_info.groupby(["venue_slug","beer_slug"]).created_at.apply(lambda x: x.apply(lambda y:dateparser.parse(y)).max()).rename("last_checkin")


venues_info_dedup = venues_info.loc[~venues_info.index.duplicated()]
venues_annotated = venues_info_dedup.join(pd.concat([venue_users, venue_rating, venue_counts,venue_last_checkin],axis=1))

venues_annotated = venues_annotated.loc[ lambda x: x.venue_url != ""]
venues_annotated = venues_annotated.loc[ venues_annotated.venue_url.notna()]
venues_annotated = venues_annotated.loc[ lambda x: x.venue_city != ""]
venues_annotated = venues_annotated.loc[ venues_annotated.venue_city.notna()]


cans = pd.read_csv("../_data/cans.csv")

for i, r in cans.iterrows():
    s = yaml.dump(r.to_dict(), default_flow_style=False)
    with open(f"../_cans/{r.code}.md","w") as f:
        f.write("---\n"),
        f.write(s)
        f.write("\n---\n")

cans["untappd_id"] = cans.untappd.str.extract('(\d*$)').astype(int)

venue_beers_annotated = venues_annotated.loc[lambda x: x.venue_id.notna()]
venue_beers_annotated = venue_beers_annotated.join(cans.set_index("untappd_id")[["code"]], on ="bid")
venue_beers_annotated = venue_beers_annotated.rename({"code":"can_code"}, axis = "columns")
venue_beers_annotated["venue_id"] = venue_beers_annotated["venue_id"].astype(int)
venue_beers_annotated.n_checkins = venue_beers_annotated.n_checkins.astype(int)

venue_beers_annotated.to_csv("../_data/venue_beers.csv")

venues_annotated = venue_beers_annotated.reset_index()[["venue_name","venue_slug","primary_category","contact","venue_id","lat","lng","venue_city" , "venue_address","venue_country","venue_city",	"venue_country",	"venue_state",'venue_url']]
venues_annotated.to_csv("../_data/venues.csv")
# Out:
# /var/folders/jb/0c007hxx54g97_0_9vdk4nk00000gn/T/ipykernel_50491/1840757843.py:9: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   pd.Series(x["venue"]),

# %%
jsons.loc[lambda x: ('media' in x) and (x['media']['items'] is not None)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [28], in <module>
# ----> 1 jsons.loc[lambda x: ('media' in x) and (x['media']['items'] is not None)]
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py:895, in _LocationIndexer.__getitem__(self, key)
#     892 axis = self.axis or 0
#     894 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py:1124, in _LocIndexer._getitem_axis(self, key, axis)
#    1122 # fall thru to straight lookup
#    1123 self._validate_key(key, axis)
# -> 1124 return self._get_label(key, axis=axis)
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py:1073, in _LocIndexer._get_label(self, label, axis)
#    1071 def _get_label(self, label, axis: int):
#    1072     # GH#5667 this will fail if the label is not present in the axis.
# -> 1073     return self.obj.xs(label, axis=axis)
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/generic.py:3738, in NDFrame.xs(self, key, axis, level, drop_level)
#    3736         raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3737 else:
# -> 3738     loc = index.get_loc(key)
#    3740     if isinstance(loc, np.ndarray):
#    3741         if loc.dtype == np.bool_:
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexes/range.py:354, in RangeIndex.get_loc(self, key, method, tolerance)
#     352         except ValueError as err:
#     353             raise KeyError(key) from err
# --> 354     raise KeyError(key)
#     355 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: False

# %%
# Out:
# 0      {'checkin_id': 953341972, 'created_at': 'Wed, ...
# 1      {'checkin_id': 953343161, 'created_at': 'Wed, ...
# 2      {'checkin_id': 953359908, 'created_at': 'Wed, ...
# 3      {'checkin_id': 953362324, 'created_at': 'Wed, ...
# 4      {'checkin_id': 953363112, 'created_at': 'Wed, ...
#                              ...
# 645    {'checkin_id': 1123179567, 'created_at': 'Sun,...
# 646    {'checkin_id': 1123203612, 'created_at': 'Sun,...
# 647    {'checkin_id': 1123850824, 'created_at': 'Thu,...
# 648    {'checkin_id': 1123853610, 'created_at': 'Thu,...
# 649    {'checkin_id': 1125017922, 'created_at': 'Sun,...
# Name: json, Length: 650, dtype: object

# %%
# Out:
# 0      {'checkin_id': 953341972, 'created_at': 'Wed, ...
# 1      {'checkin_id': 953343161, 'created_at': 'Wed, ...
# 3      {'checkin_id': 953362324, 'created_at': 'Wed, ...
# 7      {'checkin_id': 953373944, 'created_at': 'Wed, ...
# 9      {'checkin_id': 953375832, 'created_at': 'Wed, ...
#                              ...
# 629    {'checkin_id': 1122693967, 'created_at': 'Sat,...
# 630    {'checkin_id': 1122698579, 'created_at': 'Sat,...
# 635    {'checkin_id': 1122788026, 'created_at': 'Sat,...
# 636    {'checkin_id': 1122789389, 'created_at': 'Sat,...
# 646    {'checkin_id': 1123203612, 'created_at': 'Sun,...
# Name: json, Length: 306, dtype: object

# %%
import wget

# %%
checkin_pht

# %%
checkin_photos = jsons.loc[lambda x: x.apply(lambda y:('media' in y) and (y['media']['items'] is not None) and (len(y['media']['items']) > 0))].apply(lambda x:
                        pd.Series(dict(**{
                            "checkin_id":x["checkin_id"],
                            "photo":x['media']['items'][0]['photo']['photo_img_md']}
                                      ))).set_index("checkin_id")



checkin_photos.apply(
        lambda x:wget.download(x.photo,f"../assets/checkin_photos/{x.name}.jpg") if not (os.path.isfile(f"../assets/checkin_photos/{x.name}.jpg")) else None
,axis=1)
# Out:
# checkin_id
# 953341972     None
# 953343161     None
# 953362324     None
# 953373944     None
# 953375832     None
#               ...
# 1122693967    None
# 1122698579    None
# 1122788026    None
# 1122789389    None
# 1123203612    None
# Length: 306, dtype: object

# %%
# Out:
# -1 / unknown......................................................................] 160178 / 160178
# checkin_id
# 953341972      ../assets/checkin_photos/953341972.jpg
# 953343161      ../assets/checkin_photos/953343161.jpg
# 953362324      ../assets/checkin_photos/953362324.jpg
# 953373944      ../assets/checkin_photos/953373944.jpg
# 953375832      ../assets/checkin_photos/953375832.jpg
#                                ...
# 1122693967    ../assets/checkin_photos/1122693967.jpg
# 1122698579    ../assets/checkin_photos/1122698579.jpg
# 1122788026    ../assets/checkin_photos/1122788026.jpg
# 1122789389    ../assets/checkin_photos/1122789389.jpg
# 1123203612    ../assets/checkin_photos/1123203612.jpg
# Length: 306, dtype: object

# %%
ls './../assets/checkin_photos/'
# Out:
# ls: ./../assets/checkin_photos/: No such file or directory

# %%
ls './../assets/'
# Out:
# --s800
# 2022_can_web_labels/
# 2022_web_brand_assets/
# 2022_web_brand_assets_fab_logo_black-04.png
# 2022_web_brand_assets_fab_logo_black-07.png
# 2022_web_brand_assets_fab_logo_white.png
# 2022_web_brand_assets_fab_logo_word.png
# 2022_web_brand_assets_fab_logo_words.png
# 2022_web_brand_assets_fab_word.png
# 2022_web_brand_assets_logo_white_on_black.png
# aafab100/
# ads/
# balloon_wip_assets/
# balloons/
# beer_pours/
# blog/
# can_graphics/
# canart/
# cans/
# ezgif.com-gif-maker.mp4
# ezgif.com-gif-maker.webp
# fav.png
# favicon.png
# fonts/
# headshots/
# icons/
# img/
# lars/
# map/
# medusa/
# mwa/
# p4p/
# people/
# personell_qr/
# qr/
# qr-menu.svg
# somervile-half.jpg
# somerville.jpg
# somerville_chaos_bg.jpg
# somerville_chaos_bg_800.jpg
# square/
# squid.jpg
# story/
# tremendous/
# wip/

# %%
venues
# Out:
#        venue_id              venue_name              venue_slug  \
# 0     9917985.0         Untappd at Home         untappd-at-home
# 1     9917985.0         Untappd at Home         untappd-at-home
# 2     9917985.0         Untappd at Home         untappd-at-home
# 3     9917985.0         Untappd at Home         untappd-at-home
# 4           NaN                     NaN                     NaN
# ..          ...                     ...                     ...
# 645   9094692.0  Time Out Market Boston  time-out-market-boston
# 646  10188302.0               Saam Hill               saam-hill
# 647   9094692.0  Time Out Market Boston  time-out-market-boston
# 648   9094692.0  Time Out Market Boston  time-out-market-boston
# 649         NaN                     NaN                     NaN
#
#     primary_category_key primary_category        parent_category_id  \
# 0              Residence        Residence  4e67e38e036454776db1fb3a
# 1              Residence        Residence  4e67e38e036454776db1fb3a
# 2              Residence        Residence  4e67e38e036454776db1fb3a
# 3              Residence        Residence  4e67e38e036454776db1fb3a
# 4                    NaN              NaN                       NaN
# ..                   ...              ...                       ...
# 645                 Food             Food  4d4b7105d754a06374d81259
# 646            Residence        Residence  4e67e38e036454776db1fb3a
# 647                 Food             Food  4d4b7105d754a06374d81259
# 648                 Food             Food  4d4b7105d754a06374d81259
# 649                  NaN              NaN                       NaN
#
#                                             categories  \
# 0    {'count': 1, 'items': [{'category_key': 'home_...
# 1    {'count': 1, 'items': [{'category_key': 'home_...
# 2    {'count': 1, 'items': [{'category_key': 'home_...
# 3    {'count': 1, 'items': [{'category_key': 'home_...
# 4                                                  NaN
# ..                                                 ...
# 645  {'count': 2, 'items': [{'category_key': 'food_...
# 646  {'count': 1, 'items': [{'category_key': 'home_...
# 647  {'count': 2, 'items': [{'category_key': 'food_...
# 648  {'count': 2, 'items': [{'category_key': 'food_...
# 649                                                NaN
#
#                                               location  \
# 0    {'venue_address': '', 'venue_city': '', 'venue...
# 1    {'venue_address': '', 'venue_city': '', 'venue...
# 2    {'venue_address': '', 'venue_city': '', 'venue...
# 3    {'venue_address': '', 'venue_city': '', 'venue...
# 4                                                  NaN
# ..                                                 ...
# 645  {'venue_address': '401 Park Drive', 'venue_cit...
# 646  {'venue_address': '', 'venue_city': 'Altamont'...
# 647  {'venue_address': '401 Park Drive', 'venue_cit...
# 648  {'venue_address': '401 Park Drive', 'venue_cit...
# 649                                                NaN
#
#                                                contact  \
# 0                     {'twitter': '', 'venue_url': ''}
# 1                     {'twitter': '', 'venue_url': ''}
# 2                     {'twitter': '', 'venue_url': ''}
# 3                     {'twitter': '', 'venue_url': ''}
# 4                                                  NaN
# ..                                                 ...
# 645  {'twitter': '', 'venue_url': 'https://www.time...
# 646                   {'twitter': '', 'venue_url': ''}
# 647  {'twitter': '', 'venue_url': 'https://www.time...
# 648  {'twitter': '', 'venue_url': 'https://www.time...
# 649                                                NaN
#
#                                             foursquare  ... beer_abv beer_ibu  \
# 0    {'foursquare_id': '5e7b4d99c91df60008e8b168', ...  ...      4.0        0
# 1    {'foursquare_id': '5e7b4d99c91df60008e8b168', ...  ...      9.0        0
# 2    {'foursquare_id': '5e7b4d99c91df60008e8b168', ...  ...      9.0        0
# 3    {'foursquare_id': '5e7b4d99c91df60008e8b168', ...  ...      9.0        0
# 4                                                  NaN  ...      6.0        0
# ..                                                 ...  ...      ...      ...
# 645  {'foursquare_id': '5ceeec1fd552c7002d568cad', ...  ...      5.0       35
# 646  {'foursquare_id': '5f4982cf7631944f91760e59', ...  ...      6.0        0
# 647  {'foursquare_id': '5ceeec1fd552c7002d568cad', ...  ...      5.0       35
# 648  {'foursquare_id': '5ceeec1fd552c7002d568cad', ...  ...      7.5        0
# 649                                                NaN  ...      9.0        0
#
#                                              beer_slug  \
# 0      fab-fermentation-arts-atfabcans-cosmic-plankton
# 1    fab-fermentation-arts-atfabcans-johnny-get-you...
# 2    fab-fermentation-arts-atfabcans-atlantis-will-...
# 3    fab-fermentation-arts-atfabcans-johnny-get-you...
# 4    fab-fermentation-arts-atfabcans-squid-3d-citra...
# ..                                                 ...
# 645       fab-fermentation-arts-pilsner-4-peace-fabp4p
# 646  fab-fermentation-arts-squid-3d-citra-mosaic-an...
# 647       fab-fermentation-arts-pilsner-4-peace-fabp4p
# 648  fab-fermentation-arts-tales-of-the-mosaic-marv...
# 649  fab-fermentation-arts-atlantis-will-prevail-fa...
#
#                                       beer_description  \
# 0                Tart ale w/ pink guava & blood orange
# 1    Get in the jeep... and grab your raygun! This ...
# 2    Hazy, Juicy New England 2xIPA (9%). Mosaic and...
# 3    Get in the jeep... and grab your raygun! This ...
# 4    A new IPA featuring an ever-changing multi-dim...
# ..                                                 ...
# 645  American-style Pilsner, with subtle layers of ...
# 646  A new IPA featuring an ever-changing multi-dim...
# 647  American-style Pilsner, with subtle layers of ...
# 648  Lemon and peach gummies with over-ripe strawbe...
# 649  Hazy, Juicy New England 2xIPA (9%). Mosaic and...
#
#                                      beer_style has_had  beer_active  \
# 0                           Sour - Fruited Gose   False            1
# 1           IPA - Imperial / Double New England   False            1
# 2           IPA - Imperial / Double New England   False            1
# 3           IPA - Imperial / Double New England   False            1
# 4                             IPA - New England   False            1
# ..                                          ...     ...          ...
# 645                             Pilsner - Other   False            1
# 646                    IPA - New England / Hazy   False            1
# 647                             Pilsner - Other   False            1
# 648                    IPA - New England / Hazy   False            1
# 649  IPA - Imperial / Double New England / Hazy   False            1
#
#      checkin_id                       created_at rating_score
# 0     953341972  Wed, 14 Oct 2020 22:12:09 +0000         4.00
# 1     953343161  Wed, 14 Oct 2020 22:15:43 +0000         2.25
# 2     953359908  Wed, 14 Oct 2020 23:04:11 +0000         4.50
# 3     953362324  Wed, 14 Oct 2020 23:10:38 +0000         4.50
# 4     953363112  Wed, 14 Oct 2020 23:12:38 +0000         3.75
# ..          ...                              ...          ...
# 645  1123179567  Sun, 23 Jan 2022 19:23:37 +0000         0.00
# 646  1123203612  Sun, 23 Jan 2022 20:15:30 +0000         3.25
# 647  1123850824  Thu, 27 Jan 2022 18:50:59 +0000         5.00
# 648  1123853610  Thu, 27 Jan 2022 19:01:49 +0000         5.00
# 649  1125017922  Sun, 30 Jan 2022 04:48:45 +0000         4.50
#
# [650 rows x 26 columns]
